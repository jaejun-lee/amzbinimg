# %%
import importlib as imt
import datasets_v3
import datasets_v0
import catalog
import utils
import frame_autoencoder as fr

imt.reload(datasets_v3)
imt.reload(datasets_v0)
imt.reload(catalog)
imt.reload(utils) 
imt.reload(fr)
# Out:
# <module 'frame_autoencoder_v3' from '/home/ubuntu/amzbinimg/src/frame_autoencoder_v3.py'>

# %%
import datetime as dt
import tensorflow as tf

import skimage
from skimage.io import imread
from skimage.io import imsave
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense, Input, InputLayer
from tensorflow.keras.layers import Conv2D, Flatten
from tensorflow.keras.layers import Reshape, Conv2DTranspose
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.datasets import mnist
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.activations import relu
from tensorflow.keras.layers import UpSampling2D, MaxPooling2D

# %% [markdown]
# ## Reconstruct Autoencoder

# %% [markdown]
# ### load datasets for reconstruction

# %%
frame = fr.frame_autoencoder(batch_size = 128, 
                            kernel_size = 3, 
                            latent_dim = 1024, 
                            layer_filters = [16, 32, 16]
    )

# %%
frame.load_and_condition_dataset_reco()

# %% [markdown]
# ### Build Customer Encoder and Decoder

# %%
frame.load_encoder(build_encoder)
frame.load_decoder(build_decoder)

# %% [markdown]
# ### Build AutoEncoder

# %%
frame.load_autoencoder(build_autoencoder)

# %%
frame.encoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 128, 128, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 128, 128, 16)      448
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 128, 16)      64
# _________________________________________________________________
# tf_op_layer_Relu (TensorFlow multiple                  0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# tf_op_layer_Relu_1 (TensorFl multiple                  0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 16)        4624
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 16)        64
# _________________________________________________________________
# tf_op_layer_Relu_2 (TensorFl multiple                  0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# latent_vector (Dense)        (None, 1024)              4195328
# =================================================================
# Total params: 4,205,296
# Trainable params: 4,205,040
# Non-trainable params: 256
# _________________________________________________________________

# %%
frame.decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input (InputLayer)   [(None, 1024)]            0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              4198400
# _________________________________________________________________
# reshape (Reshape)            (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 16, 16, 16)        2320
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 16)        64
# _________________________________________________________________
# tf_op_layer_Relu_3 (TensorFl multiple                  0
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 32, 32, 32)        4640
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# tf_op_layer_Relu_4 (TensorFl multiple                  0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 64, 64, 16)        4624
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 64, 64, 16)        64
# _________________________________________________________________
# tf_op_layer_Relu_5 (TensorFl multiple                  0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 128, 128, 3)       435
# _________________________________________________________________
# decoder_output (Activation)  (None, 128, 128, 3)       0
# =================================================================
# Total params: 4,210,675
# Trainable params: 4,210,419
# Non-trainable params: 256
# _________________________________________________________________

# %%
frame.autoencoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 128, 128, 3)]     0
# _________________________________________________________________
# encoder (Model)              (None, 1024)              4205296
# _________________________________________________________________
# decoder (Model)              (None, 128, 128, 3)       4210675
# =================================================================
# Total params: 8,415,971
# Trainable params: 8,415,459
# Non-trainable params: 512
# _________________________________________________________________

# %%
log_dir="../logs/autoencoder_reco/train/" + dt.datetime.now().strftime("%Y%m%d-%H%M%S")
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=0.0001)
tensorboard = TensorBoard(log_dir=log_dir, histogram_freq=1)
history = frame.autoencoder.fit(x=frame.Xf_train,
                y=frame.yf_train,
                epochs=40,
                validation_split=0.2,
                batch_size=frame.batch_size,
                callbacks = [tensorboard],
                use_multiprocessing=True
)
# Out:
# Train on 21104 samples, validate on 5276 samples
# Epoch 1/40
#   128/21104 [..............................] - ETA: 12:09 - loss: 0.0262WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.306003). Check your callbacks.
# 21104/21104 [==============================] - 50s 2ms/sample - loss: 0.0105 - val_loss: 0.0055
# Epoch 2/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0046 - val_loss: 0.0040
# Epoch 3/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0037 - val_loss: 0.0034
# Epoch 4/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0033 - val_loss: 0.0032
# Epoch 5/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0031 - val_loss: 0.0030
# Epoch 6/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0029 - val_loss: 0.0028
# Epoch 7/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0028 - val_loss: 0.0027
# Epoch 8/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0026 - val_loss: 0.0026
# Epoch 9/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0025 - val_loss: 0.0026
# Epoch 10/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0025 - val_loss: 0.0025
# Epoch 11/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0024 - val_loss: 0.0024
# Epoch 12/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0024 - val_loss: 0.0024
# Epoch 13/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0023 - val_loss: 0.0023
# Epoch 14/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0023 - val_loss: 0.0023
# Epoch 15/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0022 - val_loss: 0.0023
# Epoch 16/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0022 - val_loss: 0.0022
# Epoch 17/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0022 - val_loss: 0.0022
# Epoch 18/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0021 - val_loss: 0.0022
# Epoch 19/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0021 - val_loss: 0.0022
# Epoch 20/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0021 - val_loss: 0.0021
# Epoch 21/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0020 - val_loss: 0.0022
# Epoch 22/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0020 - val_loss: 0.0021
# Epoch 23/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0020 - val_loss: 0.0021
# Epoch 24/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0020 - val_loss: 0.0021
# Epoch 25/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0020 - val_loss: 0.0021
# Epoch 26/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0019 - val_loss: 0.0020
# Epoch 27/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0019 - val_loss: 0.0020
# Epoch 28/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0019 - val_loss: 0.0022
# Epoch 29/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0019 - val_loss: 0.0020
# Epoch 30/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0019 - val_loss: 0.0020
# Epoch 31/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0019 - val_loss: 0.0021
# Epoch 32/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0019 - val_loss: 0.0020
# Epoch 33/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0018 - val_loss: 0.0020
# Epoch 34/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0018 - val_loss: 0.0020
# Epoch 35/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0018 - val_loss: 0.0020
# Epoch 36/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0018 - val_loss: 0.0019
# Epoch 37/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0018 - val_loss: 0.0019
# Epoch 38/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0018 - val_loss: 0.0019
# Epoch 39/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0018 - val_loss: 0.0019
# Epoch 40/40
# 21104/21104 [==============================] - 45s 2ms/sample - loss: 0.0018 - val_loss: 0.0019

# %%
fr.plot_history(history)

# %%
log_dir="../logs/autoencoder/evaluate/" + dt.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard = TensorBoard(log_dir=log_dir, histogram_freq=1)    
frame.autoencoder.evaluate(x=frame.Xf_test, 
                        y=frame.yf_test, 
                        batch_size=frame.batch_size, 
                        verbose=2, 
                        callbacks=[tensorboard], 
                        #max_queue_size=10, 
                        #workers=1, 
                        use_multiprocessing=False
)
# Out:
# 2932/1 - 3s - loss: 0.0019
# 0.0019187739704663155

# %%
import pickle
with open('../model/history_reco_mse_0019.pkl', 'wb') as file_pi:
        pickle.dump(history.history, file_pi)
frame.autoencoder.reset_metrics()
frame.autoencoder.save("../model/autoencoder_reco_mse_0019.h5")
frame.encoder.save("../model/encoder_reco_mse_0019.h5")
frame.decoder.save("../model/decoder_reco_mse_0019.h5")

# %%
for i in range(0,5):
        img = frame.Xf_test[i]
        fr.visualize(img,frame.encoder,frame.decoder)

# %%
# frame = fr.frame_autoencoder(batch_size = 64, 
#                             kernel_size = 3, 
#                             latent_dim = 256, 
#                             layer_filters = [64, 32, 16]
#     )
# frame.load_and_condition_dataset_feature_extraction()

frame.load_and_condition_dataset_denoise('../data/x_images_v2/', '../data/y_images_v2/')

# %%
frame.autoencoder = tf.keras.models.load_model("../model/autoencoder_reco_mse_0019.h5")
frame.encoder = tf.keras.models.load_model("../model/encoder_reco_mse_0019.h5")
frame.decoder = tf.keras.models.load_model("../model/decoder_reco_mse_0019.h5")
# Out:
# WARNING:tensorflow:No training configuration found in save file: the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file: the model was *not* compiled. Compile it manually.

# %%
for i in range(5):
        img = frame.y_train[i]
        fr.visualize(img, frame.encoder,frame.decoder)

# %%
frame.autoencoder.reset_metrics()
frame.encoder.trainable = False
optimizer = tf.keras.optimizers.Adam(
    learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, amsgrad=False,
    name='Adam'
)
frame.autoencoder.compile(loss='mse', optimizer=optimizer, sample_weight_mode="temporal")
log_dir="../logs/denoise/train/" + dt.datetime.now().strftime("%Y%m%d-%H%M%S")
#callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=0.001)
tensorboard = TensorBoard(log_dir=log_dir, histogram_freq=1)
history = frame.autoencoder.fit(x=frame.X_train,
                y=frame.y_train,
                epochs=15,
                validation_split=0.1,
                batch_size=32,
                callbacks = [tensorboard],
                use_multiprocessing=False
)
# Out:
# Train on 7217 samples, validate on 802 samples
# Epoch 1/15
# 7217/7217 [==============================] - 19s 3ms/sample - loss: 0.0018 - val_loss: 8.5538e-04
# Epoch 2/15
# 7217/7217 [==============================] - 18s 2ms/sample - loss: 6.4913e-04 - val_loss: 6.6393e-04
# Epoch 3/15
# 7217/7217 [==============================] - 18s 2ms/sample - loss: 4.6729e-04 - val_loss: 4.3949e-04
# Epoch 4/15
# 7217/7217 [==============================] - 18s 2ms/sample - loss: 3.7707e-04 - val_loss: 3.5678e-04
# Epoch 5/15
# 7217/7217 [==============================] - 18s 2ms/sample - loss: 3.5429e-04 - val_loss: 3.5226e-04
# Epoch 6/15
# 7217/7217 [==============================] - 18s 2ms/sample - loss: 2.9629e-04 - val_loss: 3.0688e-04
# Epoch 7/15
# 7217/7217 [==============================] - 18s 2ms/sample - loss: 2.7235e-04 - val_loss: 2.8092e-04
# Epoch 8/15
# 7217/7217 [==============================] - 18s 2ms/sample - loss: 2.5774e-04 - val_loss: 2.6255e-04
# Epoch 9/15
# 7217/7217 [==============================] - 18s 2ms/sample - loss: 2.8611e-04 - val_loss: 2.9200e-04
# Epoch 10/15
# 7217/7217 [==============================] - 18s 2ms/sample - loss: 2.3615e-04 - val_loss: 2.4070e-04
# Epoch 11/15
# 7217/7217 [==============================] - 18s 2ms/sample - loss: 2.3784e-04 - val_loss: 2.4106e-04
# Epoch 12/15
# 7217/7217 [==============================] - 18s 2ms/sample - loss: 2.2804e-04 - val_loss: 2.3221e-04
# Epoch 13/15
# 7217/7217 [==============================] - 18s 2ms/sample - loss: 2.0862e-04 - val_loss: 2.2518e-04
# Epoch 14/15
# 7217/7217 [==============================] - 18s 2ms/sample - loss: 2.0053e-04 - val_loss: 2.1897e-04
# Epoch 15/15
# 7217/7217 [==============================] - 18s 2ms/sample - loss: 1.9412e-04 - val_loss: 2.1137e-04

# %%
log_dir="../logs/denoise/train/" + dt.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard = TensorBoard(log_dir=log_dir, histogram_freq=1)    
frame.autoencoder.evaluate(x=frame.X_test, 
                        y=frame.y_test, 
                        batch_size=frame.batch_size, 
                        verbose=2, 
                        callbacks=[tensorboard], 
                        #max_queue_size=10, 
                        #workers=1, 
                        use_multiprocessing=False
)
# Out:
# 891/891 - 1s - loss: 2.1111e-04
# 0.0002111115105449892

# %%
fr.plot_history(history)

# %%
for i in range(5):
        img = frame.X_test[i]
        fr.visualize(img, frame.encoder,frame.decoder)

# %%
frame.autoencoder.reset_metrics()
frame.autoencoder.save("../model/autoencoder_denoise_mse_0019.h5")
frame.encoder.save("../model/encoder_denoise_mse_0019.h5")
frame.decoder.save("../model/decoder_denoise_mse_0019.h5")

# %%
for i in range(5):
        img = frame.Xf_test[i]
        fr.visualize(img,frame.encoder,frame.decoder)

# %%
frame.autoencoder = tf.keras.models.load_model("../model/autoencoder_reco_mse_0019.h5")
frame.encoder = tf.keras.models.load_model("../model/encoder_reco_mse_0019.h5")
frame.decoder = tf.keras.models.load_model("../model/decoder_reco_mse_0019.h5")

# %%
frame.load_and_condition_dataset_denoise('../data/x_images_v3/', '../data/y_images_v3/')

# %%
for i in range(5):
        img = frame.y_train[i]
        fr.visualize(img, frame.encoder,frame.decoder)

# %%
frame.autoencoder.reset_metrics()
frame.encoder.trainable = False
optimizer = tf.keras.optimizers.Adam(
    learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, amsgrad=False,
    name='Adam'
)
frame.autoencoder.compile(loss='mse', optimizer=optimizer, sample_weight_mode="temporal")
log_dir="../logs/denoise/train/" + dt.datetime.now().strftime("%Y%m%d-%H%M%S")
#callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=0.001)
tensorboard = TensorBoard(log_dir=log_dir, histogram_freq=1)
history = frame.autoencoder.fit(x=frame.X_train,
                y=frame.y_train,
                epochs=20,
                validation_split=0.1,
                batch_size=32,
                callbacks = [tensorboard],
                use_multiprocessing=False
)
# Out:
# Train on 3957 samples, validate on 440 samples
# Epoch 1/20
# 3957/3957 [==============================] - 12s 3ms/sample - loss: 0.0160 - val_loss: 0.0135
# Epoch 2/20
# 3957/3957 [==============================] - 10s 3ms/sample - loss: 0.0126 - val_loss: 0.0130
# Epoch 3/20
# 3957/3957 [==============================] - 10s 3ms/sample - loss: 0.0117 - val_loss: 0.0129
# Epoch 4/20
# 3957/3957 [==============================] - 10s 3ms/sample - loss: 0.0111 - val_loss: 0.0127
# Epoch 5/20
# 3957/3957 [==============================] - 10s 3ms/sample - loss: 0.0106 - val_loss: 0.0126
# Epoch 6/20
# 3957/3957 [==============================] - 10s 3ms/sample - loss: 0.0102 - val_loss: 0.0126
# Epoch 7/20
# 3957/3957 [==============================] - 10s 3ms/sample - loss: 0.0099 - val_loss: 0.0129
# Epoch 8/20
# 3957/3957 [==============================] - 10s 3ms/sample - loss: 0.0096 - val_loss: 0.0126
# Epoch 9/20
# 3957/3957 [==============================] - 10s 3ms/sample - loss: 0.0094 - val_loss: 0.0126
# Epoch 10/20
# 3957/3957 [==============================] - 10s 3ms/sample - loss: 0.0092 - val_loss: 0.0127
# Epoch 11/20
# 3957/3957 [==============================] - 10s 3ms/sample - loss: 0.0089 - val_loss: 0.0125
# Epoch 12/20
# 3957/3957 [==============================] - 10s 3ms/sample - loss: 0.0087 - val_loss: 0.0126
# Epoch 13/20
# 3957/3957 [==============================] - 10s 3ms/sample - loss: 0.0086 - val_loss: 0.0127
# Epoch 14/20
# 3957/3957 [==============================] - 10s 3ms/sample - loss: 0.0084 - val_loss: 0.0128
# Epoch 15/20
# 3957/3957 [==============================] - 10s 3ms/sample - loss: 0.0084 - val_loss: 0.0128
# Epoch 16/20
# 3957/3957 [==============================] - 10s 3ms/sample - loss: 0.0082 - val_loss: 0.0128
# Epoch 17/20
# 3957/3957 [==============================] - 10s 3ms/sample - loss: 0.0082 - val_loss: 0.0129
# Epoch 18/20
# 3957/3957 [==============================] - 10s 3ms/sample - loss: 0.0080 - val_loss: 0.0130
# Epoch 19/20
# 3957/3957 [==============================] - 10s 3ms/sample - loss: 0.0079 - val_loss: 0.0130
# Epoch 20/20
# 3957/3957 [==============================] - 10s 3ms/sample - loss: 0.0079 - val_loss: 0.0132

# %%
log_dir="../logs/denoise/train/" + dt.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard = TensorBoard(log_dir=log_dir, histogram_freq=1)    
frame.autoencoder.evaluate(x=frame.X_test, 
                        y=frame.y_test, 
                        batch_size=frame.batch_size, 
                        verbose=2, 
                        callbacks=[tensorboard], 
                        #max_queue_size=10, 
                        #workers=1, 
                        use_multiprocessing=False
)
# Out:
# 489/489 - 1s - loss: 0.0134
# 0.013419455014443471

# %%
fr.plot_history(history)

# %%
for i in range(5):
        img = frame.X_test[i]
        fr.visualize(img, frame.encoder,frame.decoder)

# %%
for i in range(5):
        img = frame.Xf_test[i]
        fr.visualize(img,frame.encoder,frame.decoder)

# %%
import gc
gc.collect()
# Out:
# 81691

# %%
dt.datetime.now()
# Out:
# datetime.datetime(2020, 2, 27, 22, 28, 42, 429503)

# %% [markdown]
# datetime.datetime(2020, 2, 27, 22, 28, 42, 429503)

# %%
from tensorflow.keras.callbacks import TensorBoard

# %%
# !tensorboard --logdir '/home/ubuntu/amzbinimg/logs/autoencoder/train'
# Out:
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.0.1 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %%
image = frame.X_test[1]

# %%
image.shape
# Out:
# (128, 128, 3)

# %%
type(image)
# Out:
# numpy.ndarray

# %%
pre = frame.encoder.predict(image[None])

# %%
len(pre)
# Out:
# 1

# %%
pre = pre[0]

# %%
pre.shape
# Out:
# (252,)

# %%
type(pre)
# Out:
# numpy.ndarray

# %%
pre = pre[::-1]

# %%
reco = frame.decoder.predict(pre[None])[0]

# %%
def build_encoder(frame):
    inputs = Input(shape=frame.input_shape, name='encoder_input')
    x = inputs

    x = Conv2D(filters=16, kernel_size=frame.kernel_size, strides=1, padding='same')(x)
    x = BatchNormalization(trainable=False)(x)
    x = relu(x)
    x = MaxPooling2D(pool_size = (2, 2), padding='same')(x)

    x = Conv2D(filters=32, kernel_size=frame.kernel_size, strides=1, padding='same')(x)
    x = BatchNormalization(trainable=False)(x)
    x = relu(x)
    x = MaxPooling2D(pool_size = (2, 2), padding='same')(x)

    x = Conv2D(filters=16, kernel_size=frame.kernel_size, strides=1, padding='same')(x)
    x = BatchNormalization(trainable=False)(x)
    x = relu(x)
    x = MaxPooling2D(pool_size = (2, 2), padding='same')(x)

    
    # Shape info needed to build Decoder Model
    frame.shape = K.int_shape(x)
    # Generate the latent vector
    x = Flatten()(x)
    latent = Dense(frame.latent_dim, name='latent_vector')(x)

    # Instantiate Encoder Model
    frame.encoder = Model(inputs, latent, name='encoder')
    frame.inputs = inputs

# %%
def build_decoder(frame):

    latent_inputs = Input(shape=(frame.latent_dim,), name='decoder_input')
    x = Dense(frame.shape[1] * frame.shape[2] * frame.shape[3])(latent_inputs)
    x = Reshape((frame.shape[1], frame.shape[2], frame.shape[3]))(x)


    x = Conv2DTranspose(filters=16, kernel_size=frame.kernel_size, strides=1, padding='same')(x)
    x = BatchNormalization(trainable=False)(x)
    x = relu(x)
    x = UpSampling2D((2, 2))(x)

    x = Conv2DTranspose(filters=32, kernel_size=frame.kernel_size, strides=1, padding='same')(x)
    x = BatchNormalization(trainable=False)(x)
    x = relu(x)
    x = UpSampling2D((2, 2))(x)

    x = Conv2DTranspose(filters=16, kernel_size=frame.kernel_size, strides=1, padding='same')(x)
    x = BatchNormalization(trainable=False)(x)
    x = relu(x)
    x = UpSampling2D((2, 2))(x)

    x = Conv2DTranspose(filters=3, kernel_size=frame.kernel_size, padding='same')(x)

    outputs = Activation('sigmoid', name='decoder_output')(x)

    # Instantiate Decoder Model
    frame.decoder = Model(latent_inputs, outputs, name='decoder')

# %%
def build_autoencoder(frame):
    frame.autoencoder = Model(frame.inputs, frame.decoder(frame.encoder(frame.inputs)), name='autoencoder')
    optimizer = tf.keras.optimizers.Adam(
                    learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, amsgrad=False,
                    name='Adam'
                )
    frame.autoencoder.compile(loss='mse', optimizer=optimizer)

# %%
code = frame.encoder.predict(frame.Xf_test[1][None])[0]

# %%
reco = frame.decoder.predict(code[None])[0]
plt.imshow(reco)

# %%
# mask = np.zeros(code.shape[0])
# mask[code >= 0.70] = 0
new_code = code.copy()
new_code[code <= -0.5] = 0
reco = frame.decoder.predict(new_code[None])[0]
plt.imshow(reco)

# %%
code[code >=0.70]
# Out:
# array([0.73644143, 0.763427  , 0.83547187], dtype=float32)

# %%
def visualize_features(img, encoder, decoder):
    code = encoder.predict(img[None])[0]
    
    images_per_row = 16
    num_of_features = code.shape[0]
    n_cols =  num_of_features // images_per_row
    display_grid = np.zeros((images_per_row, n_cols))
    
    for row in range(images_per_row):
        for col in range(n_cols):
            mask = np.zeros(num_of_features)
            mask[row * n_cols + col] = 1
            new_code = code.copy()
            new_code = new_code * mask
            reco = decoder.predict(new_code[None])[0]
            display_grid[row, col] = reco
    
    plt.figure(figsize= (images_per_row, n_cols))
    plt.title("Feature Representation by Decoder")
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis')

# %% [markdown]
# 16-32-64 64-32-16 512 latent 0.24
