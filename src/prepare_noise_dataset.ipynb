# %%
import importlib as imt 
import prepare_image as pm
imt.reload(pm)
# Out:
# <module 'prepare_image' from '/home/jaejun/Dropbox/dsi/capstone/amzbinimg/src/prepare_image.py'>

# %%
iter_filenames = iter(range(10000))

# %%
iter_images = pm.load_images()

# %%
images = pm.get_images(next(iter_images))

# %%
iter_columns = iter(range(10))

# %%
pm.show_images(images, column = next(iter_columns))

# %%
pm.save_images(images[68], images[48], file_name=next(iter_filenames))
# Out:
# /home/jaejun/Dropbox/dsi/capstone/amzbinimg/src/prepare_image.py:66: UserWarning: ../data/x_images/0259.png is a low contrast image
#   imsave(f"{X_IMAGE_PATH}{file_name:4d}.png", x_image)
# /home/jaejun/Dropbox/dsi/capstone/amzbinimg/src/prepare_image.py:67: UserWarning: ../data/y_images/0259.png is a low contrast image
#   imsave(f"{Y_IMAGE_PATH}{file_name:4d}.png", y_image)
